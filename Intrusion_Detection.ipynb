# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, f1_score
import math
import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
import itertools
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("Train_data.csv")
test= pd.read_csv("Test_data.csv")

# %%
train
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp  ftp_data    SF        491          0     0
# 1             0           udp     other    SF        146          0     0
# 2             0           tcp   private    S0          0          0     0
# 3             0           tcp      http    SF        232       8153     0
# 4             0           tcp      http    SF        199        420     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 25187         0           tcp      exec  RSTO          0          0     0
# 25188         0           tcp  ftp_data    SF        334          0     0
# 25189         0           tcp   private   REJ          0          0     0
# 25190         0           tcp      nnsp    S0          0          0     0
# 25191         0           tcp    finger    S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
test
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
train.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# ...

# %%
train.dtypes
# Out:
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# srv_count                        int64
# ...

# %%
corrmatrix = train.corr()
fig = plt.figure(figsize = (12, 9))

mask = np.triu(np.ones_like(train.corr()))
sns.heatmap(corrmatrix, vmax = .9, mask = mask)
# plt.savefig('Results/correlation.pdf')
plt.show()

# %%
# we will removed some columns that wont help us to make the prediction better

# %%
train.drop(columns="num_outbound_cmds", axis=1,inplace=True)
test.drop(columns="num_outbound_cmds",  axis = 1, inplace=True)

# %%
test
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
train.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# ...

# %%
test.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# ...

# %%
# There sre no missing data in our dataset therefore we are good to go.

# %%
# sns.countplot(x=train['class'])
sns.countplot(x=train['protocol_type'])
# Out:
# <Axes: xlabel='protocol_type', ylabel='count'>

# %%
sns.countplot(x=train['flag'])
# Out:
# <Axes: xlabel='flag', ylabel='count'>

# %%
sns.countplot(x = train['class'])
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# Changing the object data types to integers
def obj_to_int(df):
    for col in df.columns:
        if df[col].dtype == 'object':
                label_encoder = preprocessing.LabelEncoder()
                df[col] = label_encoder.fit_transform(df[col])
obj_to_int(train)
obj_to_int(test)

# %%
train
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
sns.countplot(x = train['protocol_type'])
# Out:
# <Axes: xlabel='protocol_type', ylabel='count'>

# %% [markdown]
#  Class:
#  Anomaly 0
#  Normal 1
#
#
#  Protocol type
#  ICMP 0
#  TCP 1
#  UDP 2

# %%
X_train = train.iloc[:,:40]
Y_train = train.iloc[:,40]
Y_train
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 25187    0
# 25188    0
# 25189    0
# 25190    0
# 25191    0
# Name: class, Length: 25192, dtype: int32

# %%
# train
Y_train
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 25187    0
# 25188    0
# 25189    0
# 25190    0
# 25191    0
# Name: class, Length: 25192, dtype: int32

# %%
# Create a Random Forest Classifier
# rfc = RandomForestClassifier()

# Initialize Recursive Feature Eelimination 
# rfe = RFE(estimator=rfc, n_features_to_select=10)

# Fit RFE on the training data
# rfe.fit(X_train, Y_train)

# Create a mapping of selected features
# feature_map = zip(rfe.get_support(), X_train.columns)

# Extract the selected features
# selected_features = [v for i, v in feature_map if i]

# selected_features

# %%
# X_train = X_train[selected_features]

# %%
X_train
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       19     9        491          0     0
# 1             0              2       41     9        146          0     0
# 2             0              1       46     5          0          0     0
# 3             0              1       22     9        232       8153     0
# 4             0              1       22     9        199        420     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 25187         0              1       16     2          0          0     0
# 25188         0              1       19     9        334          0     0
# 25189         0              1       46     1          0          0     0
# 25190         0              1       38     5          0          0     0
# 25191         0              1       17     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
# splitingt the dataset into training and test
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, train_size=0.80, random_state=2)

# %%
# x_train
x_test
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 2900          0              1       46     5          0          0     0
# 11640         0              2       46     9         28          0     0
# 16662         0              0       13     9          8          0     0
# 21545         0              1       63     5          0          0     0
# 8384          0              1       22     9        197       1463     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 18166         0              1       22     5          0          0     0
# 9934          0              1       27     5          0          0     0
# 19449         0              1       19     9       1699          0     0
# 13432         0              1       19     9         12          0     0
# 11816         0              1       46     5          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
# Feature scaling
sc_X = StandardScaler()
X_train = sc_X.fit_transform(x_train)
X_test = sc_X.fit_transform(x_test)

# %%
# len(y_test)
math.sqrt(len(y_test))
# Out:
# 70.9859140956852

# %%
# Creating a KNN classifier for K=5
Classifier = KNeighborsClassifier(n_neighbors=69, p=2, metric = "euclidean")

# %%
Classifier.fit(X_train, y_train)
# Predict on the testing set
y_pred = Classifier.predict(X_test)
y_pred
# Evaluate the accuracy of the classifier

# print("Accuracy:", accuracy)

# Generate a classification report
# report = classification_report(y_test, y_pred)
# print("Classification Report:\n", report)
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[2269   64]
#  [  48 2658]]

# %%
accuracy = accuracy_score(y_test, y_pred)
print("THE Accuracy of our model is",accuracy)
print("THE F1 score of our model is",f1_score(y_test, y_pred))
# Out:
# THE Accuracy of our model is 0.9777733677316928
# THE F1 score of our model is 0.9793662490788504

# %%
# TESTING NEW DATASET THAT HAS NOT BEED SEEN BY THE MODEL

# %%
test
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_count  dst_host_srv_count  \
# ...

# %%
y_pred = Classifier.predict(test)
print(y_pred)
pd.DataFrame(y_pred).to_csv("Class_Predicted.csv", index=False)
# Out:
# [0 0 1 ... 1 1 1]

# %%
pred_data = pd.read_csv("Class_Predicted.csv")
pred_data
# Out:
#        0
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
# ...   ..
# 22539  1
# 22540  1
# 22541  1
# 22542  1
# 22543  1
#
# [22544 rows x 1 columns]

# %%
predicted_data = test.insert(40,"Predict_class",y_pred,False)
test
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0             0              1       45     1          0          0     0
# 1             0              1       45     1          0          0     0
# 2             2              1       19     9      12983          0     0
# 3             0              0       13     9         20          0     0
# 4             1              1       55     2          0         15     0
# ...         ...            ...      ...   ...        ...        ...   ...
# 22539         0              1       49     9        794        333     0
# 22540         0              1       22     9        317        938     0
# 22541         0              1       22     9      54540       8314     0
# 22542         0              2       11     9         42         42     0
# 22543         0              1       52     1          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...
